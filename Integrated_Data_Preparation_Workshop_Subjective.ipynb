# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwathasan72-svg/Masai_IIT_AIML/blob/main/Integrated_Data_Preparation_Workshop_Subjective.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = {
    "student_id": [201, 202, 203, 204, 205, 206, 207, 201],
    "gender": ["male", "female", "male", "female", "male", "female", "male", "male"],
    "city": ["Delhi", "Mumbai", "Pune", "Delhi", "Mumbai", "Pune", "Delhi", "Delhi"],
    "age": [18, 20, None, 22, 19, None, 20, 18],
    "hours_studied": [5, 4, 6, 3, 5, 4, 4, 5],
    "attendance": [90, 95, 70, 92, 78, 96, 85, 90],
    "previous_marks": [75, 80, 60, 88, 68, 85, 70, 75],
    "placement": ["yes", "no", "yes", "no", "yes", "no", "no", "yes"],
}

df = pd.DataFrame(data)

    # Step 1: identify target and feature columns
    # TODO: exclude the identifier column from the feature set

    # Step 2: remove duplicate rows without inplace=True
    # TODO: your code here

    # Step 3: fill missing ages and convert to int
    # TODO: your code here

    # Step 4: engineer study_efficiency and high_attendance
    # TODO: your code here

    # Step 5: groupby summaries and gender distribution
    # TODO: your code here

df  # or a dict/tuple of results, as you see fit

# if __name__ == "__main__":
#     result = prepare_data(data)
#     print(result)
# Out:
#    student_id  gender    city   age  hours_studied  attendance  \
# 0         201    male   Delhi  18.0              5          90
# 1         202  female  Mumbai  20.0              4          95
# 2         203    male    Pune   NaN              6          70
# 3         204  female   Delhi  22.0              3          92
# 4         205    male  Mumbai  19.0              5          78
# 5         206  female    Pune   NaN              4          96
# 6         207    male   Delhi  20.0              4          85
# 7         201    male   Delhi  18.0              5          90
#
#    previous_marks placement
# 0              75       yes
# 1              80        no
# 2              60       yes
# 3              88        no
# 4              68       yes
# 5              85        no
# 6              70        no
# 7              75       yes

# %%
    # Step 1: identify target and feature columns
    # TODO: exclude the identifier column from the feature set

target = "placement"
df = df.drop(columns=["student_id", target])
df
# Out:
#    gender    city   age  hours_studied  attendance  previous_marks
# 0    male   Delhi  18.0              5          90              75
# 1  female  Mumbai  20.0              4          95              80
# 2    male    Pune   NaN              6          70              60
# 3  female   Delhi  22.0              3          92              88
# 4    male  Mumbai  19.0              5          78              68
# 5  female    Pune   NaN              4          96              85
# 6    male   Delhi  20.0              4          85              70
# 7    male   Delhi  18.0              5          90              75

# %%
    # Step 2: remove duplicate rows without inplace=True
    # TODO: your code here


df = pd.DataFrame(data)

# df.duplicated().sum()

df = df.drop_duplicates()
df
# Out:
#    student_id  gender    city   age  hours_studied  attendance  \
# 0         201    male   Delhi  18.0              5          90
# 1         202  female  Mumbai  20.0              4          95
# 2         203    male    Pune   NaN              6          70
# 3         204  female   Delhi  22.0              3          92
# 4         205    male  Mumbai  19.0              5          78
# 5         206  female    Pune   NaN              4          96
# 6         207    male   Delhi  20.0              4          85
#
#    previous_marks placement
# 0              75       yes
# 1              80        no
# 2              60       yes
# 3              88        no
# 4              68       yes
# 5              85        no
# 6              70        no

# %%
   # Step 3: fill missing ages and convert to int
    # TODO: your code here

df["age"] = df["age"].fillna(df["age"].mean()).astype(int)
df
# Out:
#    student_id  gender    city  age  hours_studied  attendance  previous_marks  \
# 0         201    male   Delhi   18              5          90              75
# 1         202  female  Mumbai   20              4          95              80
# 2         203    male    Pune   19              6          70              60
# 3         204  female   Delhi   22              3          92              88
# 4         205    male  Mumbai   19              5          78              68
# 5         206  female    Pune   19              4          96              85
# 6         207    male   Delhi   20              4          85              70
#
#   placement
# 0       yes
# 1        no
# 2       yes
# 3        no
# 4       yes
# 5        no
# 6        no

# %%
 # Step 4: engineer study_efficiency and high_attendance
    # TODO: your code here

df["study_efficiency"] = df["previous_marks"] / df["hours_studied"]
df["hi_attendance"] = df["attendance"] > 85
df
# Out:
#    student_id  gender    city  age  hours_studied  attendance  previous_marks  \
# 0         201    male   Delhi   18              5          90              75
# 1         202  female  Mumbai   20              4          95              80
# 2         203    male    Pune   19              6          70              60
# 3         204  female   Delhi   22              3          92              88
# 4         205    male  Mumbai   19              5          78              68
# 5         206  female    Pune   19              4          96              85
# 6         207    male   Delhi   20              4          85              70
#
#   placement  study_efficiency  hi_attendance
# 0       yes         15.000000           True
# 1        no         20.000000           True
# 2       yes         10.000000          False
# 3        no         29.333333           True
# 4       yes         13.600000          False
# 5        no         21.250000           True
# ...

# %%
  # Step 5: groupby summaries and gender distribution
    # TODO: your code here

# Compute the average hours_studied per city and the average attendance per gender using groupby.

df.groupby("city")["hours_studied"].mean()
df["gender"].value_counts(normalize = True)
df.groupby("gender")["attendance"].mean()
# Out:
# gender
# female    94.333333
# male      80.750000
# Name: attendance, dtype: float64
