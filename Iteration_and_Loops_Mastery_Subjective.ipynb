# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwathasan72-svg/Masai_IIT_AIML/blob/main/Iteration_and_Loops_Mastery_Subjective.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
orders = [
    {"customer_id": "C001", "order_amount": 1200, "status": "OK"},
    {"customer_id": "C002", "order_amount": 0,    "status": "OK"},
    {"customer_id": "C003", "order_amount": 3400, "status": "OK"},
    {"customer_id": "C004", "order_amount": 500,  "status": "OK"},
    {"customer_id": "C005", "order_amount": 800,  "status": "FRAUD"},
    {"customer_id": "C006", "order_amount": 2100, "status": "OK"},
]

totalsale = 0
for Order in orders:
  if Order["status"] == "OK" and Order["order_amount"] > 0:
    totalsale += Order["order_amount"]
  elif Order["status"] == "FRAUD":
    break


print(f"Total valid orders processed: {totalsale}")
# Out:
# Total valid orders processed: 5100
