# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwathasan72-svg/Masai_IIT_AIML/blob/main/s3_1_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The welcome-email loop

#Walk over the list ["Rahul", "Priya", "Amit", "Neha"] and print "Sending #welcome email to: <name>" for each.

email_list =["Rahul", "Priya", "Amit", "Neha"]


for email in email_list:
  print("Sending welcome email to: ", {email})
# Out:
# Sending welcome email to:  {'Rahul'}
# Sending welcome email to:  {'Priya'}
# Sending welcome email to:  {'Amit'}
# Sending welcome email to:  {'Neha'}

# %%
list_a = [1,2,3,4,5,6]

sum = 0
for sumeven in list_a:
  if sumeven % 2 == 0:
    sum =  sum + sumeven

print("Sum of even numbers : ", sum)
# Out:
# Sum of even numbers :  12

# %%
print(list(range(5)))
print(list(range(2, 6)))
print(list(range(0, 10, 3)))
# Out:
# [0, 1, 2, 3, 4]
# [2, 3, 4, 5]
# [0, 3, 6, 9]

# %%
#Given prices = [100, 200, 300], write a for loop that multiplies each price by #1.1 and prints "₹100 → ₹110.0"-style lines for each.

list_c = prices = [100, 200, 300]

for abc in list_c:
  print({abc}, ":->", round(abc*1.1,1))
# Out:
# {100} :-> 110.0
# {200} :-> 220.0
# {300} :-> 330.0

# %%
sum=0
for i in range(1,101):
  sum=sum+i
print(sum)
# Out:
# 5050

# %%
ages = [25, 30, 0, 22, 0, 40]
validage =[]

for age in ages:
  if age > 0:
    validage.append(age)
print(validage)
# Out:
# [25, 30, 22, 40]

# %%
for i in range(3):
  print("warning")
# Out:
# warning
# warning
# warning

# %%
#Print each employee and their salary in the format "Rahul earns ₹50000" using .#items().

salaries = {"Rahul": 50000, "Priya": 75000, "Amit": 45000}

for name, salary in salaries.items():
  print(name, "earns ₹", salary)
  #print(salaries.items())
# Out:
# Rahul earns ₹ 50000
# Priya earns ₹ 75000
# Amit earns ₹ 45000

# %%
timer = 3
flag= True
while(flag):
  print(timer)
  timer = timer -1

  if timer ==1:
   print("liftoff")
   flag = False
# Out:
# 3
# 2
# liftoff

# %%
my_files = ["clean", "clean", "CORRUPTED", "clean", "clean"]

for i in my_files:
  if i == "CORRUPTED":
    print("CRITICAL ERROR")
    break
  else:
    print(i)
# Out:
# clean
# clean
# CRITICAL ERROR

# %%
models = {"Model_A": 88, "Model_B": 95, "Model_C": 72, "Model_D": 91}

for name, accuracy in models.items():
  if accuracy > 90:
    print(name, "is ready for production")
  else:
    print(name, "need more training")
# Out:
# Model_A need more training
# Model_B is ready for production
# Model_C need more training
# Model_D is ready for production
