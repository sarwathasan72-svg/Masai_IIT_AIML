# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwathasan72-svg/Masai_IIT_AIML/blob/main/s1_2_homework_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Create a list called subjects with these five items: "Maths", "Physics", #"Chemistry", "Biology", "English". Print it.

subjects = ["Maths", "Physics", "Chemistry", "Biology", "English"]
print(subjects)
# Out:
# ['Maths', 'Physics', 'Chemistry', 'Biology', 'English']

# %%
#Print the first subject.
print("First Subject :" , subjects[0])
# Out:
# First Subject Maths

# %%
print("Last Subject :", subjects[-1])
# Out:
# Last Subject : English

# %%
#Print the third subject (remember — Python counts from 0).
print("Third Subject :", subjects[2])
# Out:
# Third Subject : Chemistry

# %%
print("First 3 Subjects : ", subjects[0:3])
# Out:
# First 3 Subjects :  ['Maths', 'Physics', 'Chemistry']

# %%
print("Last 2 Subjects : ", subjects[-2:])
# Out:
# Last 2 Subjects :  ['Biology', 'English']
