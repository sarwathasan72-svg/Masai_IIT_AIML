# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwathasan72-svg/Masai_IIT_AIML/blob/main/s1_2_homework_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Build List
subjects = {"Maths", "Physics", "Chemistry", "Biology", "English"}
print(subjects)
# Out:
# {'Physics', 'English', 'Biology', 'Chemistry', 'Maths'}

# %%
# Snippet C
nums = [3, 1, 4, 1, 5]
nums.sort(reverse=True)
print(nums[0])
# Out:
# 5

# %%
# Snippet D
single = (99)
print(type(single))
# Out:
# <class 'int'>

# %%
point = (12.9716, 77.5946)
lat, lon = point
print(f"Latitude: {lat}, Longitude: {lon}")
# Out:
# Latitude: 12.9716, Longitude: 77.5946

# %%
point2 = (19.0760, 72.8777, 14)
lat, lon = point2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4304/2096199590.py in <cell line: 0>()
#       1 point2 = (19.0760, 72.8777, 14)
# ----> 2 lat, lon = point2
#
# ValueError: too many values to unpack (expected 2)

# %%
# Snippet B
names = ["Alice", "Bob", "Charlie"]
names.append(["Dave", "Eve"])
print(len(names))
# Out:
# 4

# %%
age = 20
if (age > 60):
  print('Free')

elif (age > 30):
  print('Half Price')
else:
  print('Full Price')
# Out:
# Full Price

# %%
students = ["Aarav", "Priya", "Ravi", "Sneha", "Kiran"]
students.append("Divya")
print(students)
students.remove("Ravi")
print(students)
scores= [85, 92, 78, 90, 88]
scores.sort(reverse=True)

top_3_scores = scores[:3]

print("Top 3 Scores:", top_3_scores)
# Out:
# ['Aarav', 'Priya', 'Ravi', 'Sneha', 'Kiran', 'Divya']
# ['Aarav', 'Priya', 'Sneha', 'Kiran', 'Divya']
# Top 3 Scores: [92, 90, 88]

# %%
topper_record = ("Priya", 95, "A+")
topper_name, topper_score, topper_grade = topper_record
print(topper_name)
print(topper_score)
print(topper_grade)

print(f"Topper: {topper_name} | score : { topper_score} | Grade: {topper_grade}")
# Out:
# Priya
# 95
# A+
# Topper: Priya | score : 95 | Grade: A+

# %%
age = 15

if age < 12:
    print("Ticket price: $5")
elif age < 18:
    print("Ticket price: $10")
else:
    print("Ticket price: $15")
# Out:
# Ticket price: $10
